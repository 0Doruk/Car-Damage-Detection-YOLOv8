# %%
# 1. Zip dosyasını kopyala (Klasör adının 'Projeler' -P büyük- olduğundan emin ol)
# !cp /content/drive/MyDrive/Projeler/damage-car-1.zip /content/

# 2. Sessizce zipten çıkar
# !unzip -q /content/damage-car-1.zip -d /content/

print("✅ Veri seti Colab hafızasına başarıyla taşındı ve açıldı!")
# Out:
# ✅ Veri seti Colab hafızasına başarıyla taşındı ve açıldı!

# %%
from google.colab import files
files.download('/content/runs/detect/rs_hasar_v2/weights/best.pt')

# %%
from ultralytics import YOLO

# 1. Drive'daki son ağırlığı yükle (Beyin nakli yapıyoruz)
model = YOLO('/content/drive/MyDrive/Projeler/rs_hasar_final_model.pt')

# 2. Eğitimi 100 epoch'a tamamla
model.train(
    data='/content/damage-car-1/data.yaml',
    epochs=100,      # Toplam hedefimiz 100 olsun
    imgsz=640,       # Çözünürlüğü yüksek tutalım
    device=0,        # Tesla T4'ü kullanmaya devam
    name='rs_hasar_v3_uzman',
    patience=20      # Eğer 20 tur boyunca gelişme olmazsa otomatik durdur (Overfitting'i önler)
)
# Out:
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# YOLOv8 kütüphanesini kuralım
# !pip install ultralytics

from ultralytics import YOLO

# Modeli ve GPU'yu (device=0) ayarla
model = YOLO('yolov8n.pt')

# EĞİTİM (30 Epoch - Tesla T4 ile yaklaşık 15-20 dakika)
results = model.train(
    data='/content/damage-car-1/data.yaml',
    epochs=30,
    imgsz=640,
    device=0,
    name='rs_hasar_v2'
)

# KRİTİK ADIM: Eğitim biter bitmez modeli Drive'a yedekle!
# !cp /content/runs/detect/rs_hasar_v2/weights/best.pt /content/drive/MyDrive/Projeler/rs_hasar_final_model.pt
print("🔥 İŞLEM TAMAM: Model eğitildi ve Drive'a yedeklendi!")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.7 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
